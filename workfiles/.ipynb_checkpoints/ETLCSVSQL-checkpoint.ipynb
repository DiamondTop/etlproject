# %%
import pandas as pd
from sqlalchemy import create_engine
import pandas_datareader as web

# %%
csv_file = "../Resources/pharma_companies_stock_info_2018.csv"
customer_data = pd.read_csv(csv_file)
customer_data.head
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-9d27831d3b6f> in <module>
#       1 csv_file = "../Resources/pharma_companies_stock_info_2018.csv"
# ----> 2 customer_data = pd.read_csv(csv_file)
#       3 customer_data.head
#
# ...

# %%
abbv_monthly_returns = ABBV['Adj Close'].resample('M').ffill().pct_change()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-85472b88961c> in <module>
# ----> 1 abbv_monthly_returns = ABBV['Adj Close'].resample('M').ffill().pct_change()
#
# NameError: name 'ABBV' is not defined

# %%
data = response.json()

# %%
rds_connection_string = "postgres:2305nseW@localhost:5432/pharma_companies_stock_info_2018_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

#engine = create_engine('postgresql://postgres:2305nseW@localhost:5432/employees_db')

# %%
engine.table_names()
# Out:
# []

# %%
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2261         try:
# -> 2262             return fn()
#    2263         except dialect.dbapi.Error as e:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759         if not fairy:
# --> 760             fairy = _ConnectionRecord.checkout(pool)
#     761
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
# ...
